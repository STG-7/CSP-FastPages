# %% [markdown]
# #  Big Idea 2 Quiz Blog - Shaurya Goel
# > Big Idea 2 Quiz Blog
# - toc: true

# %% [markdown]
# # Overall Score 23/25

# %%
from PIL import Image

score = Image.open("../images/overall.png")
display(score)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1875x402>

# %% [markdown]
# # Correcting Wrong Answers

# %%
from PIL import Image

wrong1 = Image.open("../images/wrong1.png")
wrong2 = Image.open("../images/wrong2.png")
display(wrong1)
display(wrong2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1762x557>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1581x771>

# %% [markdown]
# # Q2 Correction
# Lossless compression algorithms are guaranteed to be able to reconstruct the original data, while lossy compression algorithms are not.
#
# # Q21 Correction
# Sorting by year will sort the spreadsheet on column C from least to greatest. Filtering by year will remove 21 Correctionany entries with unknown years. Filtering by photographer will remove any entries with unknown photographers. Since the order of the entries is not affected by the filters, the photograph with the lowest year value will be in the first row of the spreadsheet.
