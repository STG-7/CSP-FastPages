# %% [markdown]
# #  STEM at CSUSM Extra Credit Blog (Part 2) - Shaurya Goel
# > 3/28 After School Event Blog (Part 2)
# - toc: true

# %% [markdown]
# ## Research at CSUSM
#
# ### Cancer Cell Research
#
# The research projects in the Cancer Cell Research program are often interdisciplinary and may involve molecular biology, biochemistry, genetics, and other fields. Students in the program may work on projects such as identifying novel cancer biomarkers, developing new cancer therapies, or investigating the underlying mechanisms of cancer growth and metastasis.
#
# Students in the program have the opportunity to work closely with faculty members and gain hands-on research experience. They may also have the opportunity to present their research at conferences or publish their findings in scientific journals.
#
# Overall, the Cancer Cell Research program at CSUSM provides students with an opportunity to make meaningful contributions to the field of cancer research while gaining valuable research skills and experience.
#
# ### Materials Resarch
#
# The program aims to advance our understanding of the fundamental principles governing the behavior of materials and to develop new materials with desirable properties for a wide range of applications. Research projects in the program may involve the synthesis and characterization of new materials, the investigation of the structure-property relationships of materials, or the development of new techniques for materials analysis.
#
# Students in the Materials Research program have the opportunity to work closely with faculty members and gain hands-on research experience. They may also have the opportunity to present their research at conferences or publish their findings in scientific journals.
#
# ### Artifical Intelligence Research
#
# The program aims to advance our understanding of AI and to develop new AI techniques and applications that can address real-world problems. Research projects in the program may involve machine learning, natural language processing, computer vision, robotics, or other AI-related topics.
#
# Students in the AI Research program have the opportunity to work closely with faculty members and gain hands-on research experience. They may also have the opportunity to present their research at conferences or publish their findings in scientific journals.
#
# The AI Research program at CSUSM also collaborates with industry partners to provide students with real-world experience in AI. For example, students may have the opportunity to work on AI projects for local companies or participate in internships with AI-focused organizations.
#
# Overall, the AI Research program at CSUSM provides students with an opportunity to make meaningful contributions to the field of artificial intelligence while gaining valuable research skills and experience. Graduates from the program may go on to pursue careers in AI, data science, or related fields or continue their education in graduate programs in AI or related disciplines.
#
# ### Other Researches
# - Studying Metgorities
# - Ecologyst Researchers

# %%
from PIL import Image

AI = Image.open("../images/ai.jpg")
display(AI)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x653>

# %% [markdown]
# ### Scholarships and Grants
#
# Question: What is the difference between a Grant and a Scholarship?
# Answer: Scholarship is privatley funded whereas grant is government funded.
#
# - Apply for FAFSA, student gov.
# - Check student email for scholarhsip opportunities sent by the school/your
# - Google is your best friend
#
# ### Life After CSUSM
# - After graduating, many people start workign in private industries and for the man's case he got an internship in Safari Park
# - Some people go into graduate school.
# - Higher Pay Rise to get a Masters Degree, and some companies will pay computer scientists to get a Masters Degree
# - Some Universities will pay for PHD and maybe even Masters Degree

# %% [markdown]
# ## Reflection
#
# In conclusion, I gained a lot of knowledge about Cal States in general and Cal State San Marcos in particular. I also gained a lot of knowledge about how college financing functions. Many people gave me advice on how to avoid using loans, or if I did, they stressed the need of using subsidized loans because they will have a smaller impact in the long run. They also provided us with advice on how to apply for scholarships in various ways. I also learnt about the several clubs and programs that Cal State San Marcos offers, as well as the different majors that I can choose from.
#
# John, the individual giving the presentation, also discussed how being Mexican or Mexican-American led to his receiving scholarships. While diversity is becoming more and more important in today's societies to help establish a diverse college environment, this can also benefit me. As is the case for the majority of college students, he was able to transfer from a community college to Cal State San Marcos and pay off all of his loans before the end of his senior year. We also discussed how to transfer across universities.
#
# They discussed how each department would have its own set of requirements for admission as well as specific departments within each department. If I attended the school, I would learn more about the CyberSecurity Club because it sounds fascinating and I have experience with it in the past, which would help me feel more at home. If I attended the school, I'd probably enroll in a course in computer engineering, information sciences, or software engineering.
#
# As cyber security is crucial for the globe and because it seems like a lot of fun, I could also give it a try. This is especially true in the modern world, where the majority of information is being saved online. The future of protecting information and ideology is data protection.
