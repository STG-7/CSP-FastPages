# %% [markdown]
# # MCQ Test #4 Blog - Shaurya Goel
# > MCQ Test #4 Blog
# - toc: true

# %% [markdown]
# # Overall Score (49/50)

# %%
from PIL import Image

overallscore = Image.open("../images/blahblah.png")
display(overallscore)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1887x761>

# %% [markdown]
# # Correcting Wrong Answers

# %%
from PIL import Image

wrong = Image.open("../images/final22.png")
display(wrong)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1633x702>

# %% [markdown]
# ### Why D is incorrect
# **While removing four links could isolate computer F from computer E, it is not the minimum number required to accomplish this.**
#
# ### Why C is correct
# **Any line between two computers represents a way for them to communicate with each other, and a communication between two computers can go through other computers. If the links from F to G, from F to A, and from F to E were broken, it would not be possible for computers E and F to communicate.**
